# %%
import os, sys
from dotenv import load_dotenv
load_dotenv("../.env")  # take environment variables
PROJECT_ROOT = os.environ.get("PROJECT_ROOT")
sys.path.append(PROJECT_ROOT)

import numpy as np
import pandas as pd

from glob import glob
import utils.PATHS as PATHS
# import utils.emr_utils as emr_utils
# import utils.load_utils as load_utils

# %% [markdown]
# ## Notes
#
# **ATTENTION: Consider both Problem List and Diagnosis subject areas.**

# %%
dd_fp_list = glob(os.path.join(PATHS.DRUG_DISPENSED, "*.csv"))

# %%
test = pd.read_csv(dd_fp_list[0])
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145344 entries, 0 to 145343
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Institution Code           145344 non-null  object
#  1   Patient ID                 145344 non-null  object
#  2   Date of Birth              145344 non-null  object
#  3   Gender                     145344 non-null  object
#  4   Race                       145337 non-null  object
#  5   Country of Residence       2395 non-null    object
#  6   Resident Indicator         145339 non-null  object
#  7   Case No                    145344 non-null  object
#  8   Visit No                   145344 non-null  object
#  9   Drug Code                  3245 non-null    object
#  10  Drug Name                  145344 non-null  object
#  11  Drug Strength              127116 non-null  object
#  12  Drug Form                  140466 non-null  object
#  13  Generic Drug Id            140466 non-null  object
#  14  Generic Drug Name          140466 non-null  object
#  15  DRG Code                   145344 non-null  object
#  16  DRG Code (AR-DRG V6.0)     145344 non-null  object
#  17  Drug Status                140689 non-null  object
#  18  Item Primary UOM           140957 non-null  object
#  19  Drug Prescribed Date From  145344 non-null  object
#  20  Drug Prescribed Date To    145344 non-null  object
#  21  Admit/Visit Date           145344 non-null  object
#  22  Case Start Date            0 non-null       float64
#  23  Case End Date              0 non-null       float64
#  24  Add Date                   145344 non-null  object
#  25  Start Date                 145344 non-null  object
#  26  Prescribed Quantity UOM    139872 non-null  object
#  27  Admit Source Code          145344 non-null  object
#  28  Admit Source Description   145344 non-null  object
#  29  Case Status Code           145344 non-null  object
#  30  Case Status Description    145344 non-null  object
#  31  Case Type Code             145344 non-null  object
#  32  Case Type Description      145344 non-null  object
# dtypes: float64(2), object(31)
# memory usage: 36.6+ MB

# %%
test.iloc[:,-8:]
# Out:
#         Start Date Prescribed Quantity UOM Admit Source Code  \
# 0       2015-12-18                     TAB        EXPUNKNOWN
# 1       2015-12-12                     SYR        EXPUNKNOWN
# 2       2015-12-16                     CAP        EXPUNKNOWN
# 3       2015-12-16                     TAB        EXPUNKNOWN
# 4       2015-12-16                     TAB        EXPUNKNOWN
# ...            ...                     ...               ...
# 145339  2015-12-24                     BOT        EXPUNKNOWN
# 145340  2015-12-26                  AMPVIA        EXPUNKNOWN
# 145341  2015-12-26                     BOT        EXPUNKNOWN
# 145342  2015-12-26                  AMPVIA        EXPUNKNOWN
# 145343  2015-12-26                  AMPVIA        EXPUNKNOWN
#
#        Admit Source Description Case Status Code Case Status Description  \
# 0              Expected Unknown       EXPUNKNOWN        Expected Unknown
# 1              Expected Unknown       EXPUNKNOWN        Expected Unknown
# 2              Expected Unknown       EXPUNKNOWN        Expected Unknown
# 3              Expected Unknown       EXPUNKNOWN        Expected Unknown
# 4              Expected Unknown       EXPUNKNOWN        Expected Unknown
# ...                         ...              ...                     ...
# 145339         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 145340         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 145341         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 145342         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 145343         Expected Unknown       EXPUNKNOWN        Expected Unknown
#
#        Case Type Code Case Type Description
# 0                   O            Outpatient
# 1                   O            Outpatient
# 2                   O            Outpatient
# 3                   O            Outpatient
# 4                   O            Outpatient
# ...               ...                   ...
# 145339              O            Outpatient
# 145340              O            Outpatient
# 145341              O            Outpatient
# 145342              O            Outpatient
# 145343              O            Outpatient
#
# [145344 rows x 8 columns]

# %%
test[["Add Date", "Start Date"]].head(200)
# Out:
#                 Add Date  Start Date
# 0    2015-12-18 12:17:07  2015-12-18
# 1    2015-12-12 08:41:50  2015-12-12
# 2    2015-12-16 12:27:59  2015-12-16
# 3    2015-12-16 12:27:58  2015-12-16
# 4    2015-12-16 12:27:59  2015-12-16
# ..                   ...         ...
# 195  2015-12-07 14:45:30  2015-12-07
# 196  2015-12-07 14:46:17  2015-12-07
# 197  2015-12-24 10:12:57  2015-12-24
# 198  2015-12-24 10:12:57  2015-12-24
# 199  2015-12-24 10:12:35  2015-12-24
#
# [200 rows x 2 columns]

# %%
test[["Case Start Date", "Case End Date"]].head(200)
# Out:
#      Case Start Date  Case End Date
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ..               ...            ...
# 195              NaN            NaN
# 196              NaN            NaN
# 197              NaN            NaN
# 198              NaN            NaN
# 199              NaN            NaN
#
# [200 rows x 2 columns]

# %%
test[["Drug Prescribed Date From", "Drug Prescribed Date To"]].head(200)
# Out:
#     Drug Prescribed Date From Drug Prescribed Date To
# 0                  2015-12-18              2015-12-25
# 1                  2015-12-12              2016-01-09
# 2                  2015-12-16              2015-12-16
# 3                  2015-12-16              2015-12-16
# 4                  2015-12-16              2015-12-16
# ..                        ...                     ...
# 195                2015-12-07              2015-12-07
# 196                2015-12-07              2015-12-07
# 197                2015-12-24              2015-12-24
# 198                2015-12-24              2015-12-24
# 199                2015-12-24              2015-12-24
#
# [200 rows x 2 columns]

# %%
test[["Drug Code", "Drug Name", "Drug Strength", "Drug Form", "Generic Drug Id", "Generic Drug Name", "DRG Code", "DRG Code (AR-DRG V6.0)"]]
# Out:
#        Drug Code                                        Drug Name  \
# 0            NaN                            Paracetamol 500mg Tab
# 1            NaN                    Etanercept 50mg/mL PF Syringe
# 2            NaN                   CALCIFEROL 50,000 UNITS TABLET
# 3            NaN  Calcium Carbonate 450mg, Vitamin D 200 unit Tab
# 4            NaN                          MetFORMIN HCl 500mg Tab
# ...          ...                                              ...
# 145339       NaN                  Tears Naturale II Eye Drop 15mL
# 145340       NaN                   Atropine Sulfate 600mcg/mL Inj
# 145341       NaN                    Glyceryl Trinitrate 0.5mg Tab
# 145342       NaN             Lidocaine (P/Free) 1% (50mg/5mL) Inj
# 145343       NaN                          MetoCLOPramide INJ 10MG
#
#           Drug Strength    Drug Form Generic Drug Id  \
# 0                 500mg          TAB             478
# 1               50mg/mL          SYR             854
# 2            50000 UNIT          TAB              96
# 3       450mg; 200 unit          TAB             105
# 4                 500mg          TAB             400
# ...                 ...          ...             ...
# 145339              NaN          EYE             622
# 145340        600mcg/mL  INJ AMP&VIA              54
# 145341            0.5mg           SL             297
# 145342           1% 5mL  INJ AMP&VIA             367
# 145343         10MG/2ML  INJ AMP&VIA             409
#
#                    Generic Drug Name    DRG Code DRG Code (AR-DRG V6.0)
# 0                        Paracetamol     Unknown                Unknown
# 1                         Etanercept     Unknown                Unknown
# 2                         Calciferol  EXPUNKNOWN             EXPUNKNOWN
# 3       Calcium Carbonate, Vitamin D  EXPUNKNOWN             EXPUNKNOWN
# 4                          MetFORMIN  EXPUNKNOWN             EXPUNKNOWN
# ...                              ...         ...                    ...
# 145339                Tears Naturale     Unknown                Unknown
# 145340                      Atropine     Unknown                Unknown
# 145341           Glyceryl Trinitrate     Unknown                Unknown
# 145342                     Lidocaine     Unknown                Unknown
# 145343                MetoCLOPramide     Unknown                Unknown
#
# [145344 rows x 8 columns]

# %%
# "DRG Code", "DRG Code (AR-DRG V6.0)" # diagnosis related group
test["DRG Code"].value_counts()
# Out:
# DRG Code
# EXPUNKNOWN    122467
# Unknown        22877
# Name: count, dtype: int64

# %%
test["DRG Code (AR-DRG V6.0)"].value_counts()
# Out:
# DRG Code (AR-DRG V6.0)
# EXPUNKNOWN    122467
# Unknown        22877
# Name: count, dtype: int64

# %%
test["Drug Status"].value_counts()
# Out:
# Drug Status
# STDTABCAP     54724
# 02            34143
# STDL2         33869
# STDCRMOINT     4634
# STDMIX         3908
# 07             1045
# NF              939
# 06              750
# STDINSUL        708
# STDEEN          671
# STDINHAL        573
# 03              517
# SVC             453
# 05              431
# 14              430
# STDSOL1         415
# STDITEM         356
# STDINFINJ       331
# STDSUPP         249
# SVL             211
# 22              208
# STDSOL4         194
# 08              158
# STDWEEK         144
# STDSOL2         137
# 04              132
# STDL2ORG        110
# 13               61
# CT               53
# 20               51
# 70               30
# 15               29
# 10               18
# 60                3
# STDPOW            2
# 19                1
# 16                1
# Name: count, dtype: int64

# %%
test.head()
# Out:
#   Institution Code            Patient ID Date of Birth  Gender     Race  \
# 0              SGH  31d385b313558357cc92    1993-09-01  FEMALE      NaN
# 1              SGH  b109f71856c858ec5aaa    1966-01-01    MALE      NaN
# 2              SGH  036017bc373eaa70e386    1955-08-01  FEMALE  Chinese
# 3              SGH  036017bc373eaa70e386    1955-08-01  FEMALE  Chinese
# 4              SGH  036017bc373eaa70e386    1955-08-01  FEMALE  Chinese
#
#   Country of Residence Resident Indicator               Case No  \
# 0                  NaN                NaN  e99d5ccf7a9a6cf00fa7
# 1                  NaN                NaN  034bc6d95a0702b8ecc8
# 2                  NaN                  N  616c710f92d9bc4480fc
# 3                  NaN                  N  616c710f92d9bc4480fc
# 4                  NaN                  N  616c710f92d9bc4480fc
#
#                Visit No Drug Code  ... Case End Date             Add Date  \
# 0  e99d5ccf7a9a6cf00fa7       NaN  ...           NaN  2015-12-18 12:17:07
# 1  034bc6d95a0702b8ecc8       NaN  ...           NaN  2015-12-12 08:41:50
# 2  94d720b95aa70d97a8b5       NaN  ...           NaN  2015-12-16 12:27:59
# 3  94d720b95aa70d97a8b5       NaN  ...           NaN  2015-12-16 12:27:58
# 4  94d720b95aa70d97a8b5       NaN  ...           NaN  2015-12-16 12:27:59
#
#    Start Date Prescribed Quantity UOM Admit Source Code  \
# 0  2015-12-18                     TAB        EXPUNKNOWN
# 1  2015-12-12                     SYR        EXPUNKNOWN
# 2  2015-12-16                     CAP        EXPUNKNOWN
# 3  2015-12-16                     TAB        EXPUNKNOWN
# 4  2015-12-16                     TAB        EXPUNKNOWN
#
#   Admit Source Description Case Status Code Case Status Description  \
# 0         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 1         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 2         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 3         Expected Unknown       EXPUNKNOWN        Expected Unknown
# 4         Expected Unknown       EXPUNKNOWN        Expected Unknown
#
#   Case Type Code Case Type Description
# 0              O            Outpatient
# 1              O            Outpatient
# 2              O            Outpatient
# 3              O            Outpatient
# 4              O            Outpatient
#
# [5 rows x 33 columns]

# %% [markdown]
# ## End.
